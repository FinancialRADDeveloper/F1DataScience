# %%
import os
import pandas as pd
import numpy as np

# %%
pitstops_df = pd.read_csv('F1KaggleData/pitStops.csv')

# %%
display(pitstops_df.sample(10))

pitstops_df.describe()

earliest_race = pitstops_df['raceId'].min()
latest_race = pitstops_df['raceId'].max()

display('Earliest race: {} Latest race: {}'.format(earliest_race, latest_race))
# Out:
#       raceId  driverId  stop  lap      time duration  milliseconds
# 3659     914       154     4   34  16:33:58   23.745         23745
# 36       841       814     2   36  18:00:48   24.332         24332
# 4556     945       832     2   28  17:54:59   22.063         22063
# 2333     884       814     2   19  14:32:58   19.792         19792
# 6079     983         1     1   26  15:45:40   23.489         23489
# 5762     974        18     2   39  14:54:53   26.057         26057
# 1008     857        30     2   50  16:19:55   21.482         21482
# 488      848        17     3   42  15:17:11   20.367         20367
# 3658     914         8     4   34  16:33:52   24.173         24173
# 2771     894        20     1   11  15:23:22   22.662         22662
# 'Earliest race: 841 Latest race: 988'

# %%
# now lets work out the races we are talking about to see what the data spans over 

races_df = pd.read_csv('F1KaggleData/races.csv')
display(races_df.sample(10))

display(races_df.loc[races_df['raceId'] == earliest_race])
display(races_df.loc[races_df['raceId'] == latest_race])

display(races_df.loc[races_df['raceId'] == 858])
# ok, this is enough data to work with 
display(races_df.loc[858])
# Out:
#      raceId  year  round  circuitId                  name        date  \
# 784     785  1956      2          6     Monaco Grand Prix  1956-05-13
# 652     653  1970     11         52   Canadian Grand Prix  1970-09-20
# 651     652  1970     10         14    Italian Grand Prix  1970-09-06
# 670     671  1968      5         39      Dutch Grand Prix  1968-06-23
# 62       63  2006     11          8     French Grand Prix  2006-07-16
# 309     310  1991      6         32    Mexican Grand Prix  1991-06-16
# 103     104  2004     15         14    Italian Grand Prix  2004-09-12
# 537     538  1978     12         23   Austrian Grand Prix  1978-08-13
# 198     199  1998      9          9    British Grand Prix  1998-07-12
# 256     257  1994      1         18  Brazilian Grand Prix  1994-03-27
#
#          time                                                url
# 784            http://en.wikipedia.org/wiki/1956_Monaco_Grand...
# 652            http://en.wikipedia.org/wiki/1970_Canadian_Gra...
# 651            http://en.wikipedia.org/wiki/1970_Italian_Gran...
# 670            http://en.wikipedia.org/wiki/1968_Dutch_Grand_...
# 62   14:00:00  http://en.wikipedia.org/wiki/2006_French_Grand...
# 309            http://en.wikipedia.org/wiki/1991_Mexican_Gran...
# 103            http://en.wikipedia.org/wiki/2004_Italian_Gran...
# 537            http://en.wikipedia.org/wiki/1978_Austrian_Gra...
# 198            http://en.wikipedia.org/wiki/1998_British_Gran...
# 256            http://en.wikipedia.org/wiki/1994_Brazilian_Gr...
#      raceId  year  round  circuitId                   name        date  \
# 839     841  2011      1          1  Australian Grand Prix  2011-03-27
#
#          time                                                url
# 839  06:00:00  http://en.wikipedia.org/wiki/2011_Australian_G...
#      raceId  year  round  circuitId                  name        date  \
# 975     988  2017     20         24  Abu Dhabi Grand Prix  2017-11-26
#
#          time                                                url
# 975  13:00:00  https://en.wikipedia.org/wiki/2017_Abu_Dhabi_G...
#      raceId  year  round  circuitId                  name        date  \
# 856     858  2011     18         24  Abu Dhabi Grand Prix  2011-11-13
#
#          time                                                url
# 856  13:00:00  http://en.wikipedia.org/wiki/2011_Abu_Dhabi_Gr...
# raceId                                                     860
# year                                                      2012
# round                                                        1
# circuitId                                                    1
# name                                     Australian Grand Prix
# date                                                2012-03-18
# time                                                  06:00:00
# url          http://en.wikipedia.org/wiki/2012_Australian_G...
# Name: 858, dtype: object

# %%
# there looks like there is some weird data, where the pit stops take waaay too long
pitstops_df.sort_values('milliseconds', ascending=True, inplace=True)

display(pitstops_df.head(10))

drivers_df = pd.read_csv('F1KaggleData/drivers.csv')
display(drivers_df.head(2))
driver_with_the_short_stop = drivers_df.loc[drivers_df['driverId'] == 813]
display(driver_with_the_short_stop)
# Out:
#       raceId  driverId  stop  lap      time duration  milliseconds
# 1037     858       813     2   30  17:58:49   12.897         12897
# 1044     858       811     3   36  18:09:34   12.959         12959
# 693      851         1     6   56  15:30:48   13.173         13173
# 632      851       813     2   16  14:31:22   13.186         13186
# 1640     870        30     2    4  14:12:58   13.199         13199
# 655      851       815     3   32  14:56:05   13.201         13201
# 1692     870       813     3   52  15:23:48   13.206         13206
# 1399     864        13     2   28  14:46:33   13.259         13259
# 2330     884       813     2   13  14:23:55   13.266         13266
# 1402     864        20     3   30  14:49:35   13.335         13335
#    driverId driverRef  number code forename   surname         dob nationality  \
# 0         1  hamilton    44.0  HAM    Lewis  Hamilton  07/01/1985     British
# 1         2  heidfeld     NaN  HEI     Nick  Heidfeld  10/05/1977      German
#
#                                            url
# 0  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1   http://en.wikipedia.org/wiki/Nick_Heidfeld
#      driverId  driverRef  number code forename    surname         dob  \
# 812       813  maldonado    13.0  MAL   Pastor  Maldonado  09/03/1985
#
#     nationality                                            url
# 812  Venezuelan  http://en.wikipedia.org/wiki/Pastor_Maldonado

# %%
canada_2016_race_id = races_df.loc[(races_df['name'] == 'Canadian Grand Prix') & (races_df['year'] == 2016)]['raceId']

display(int(canada_2016_race_id))

pitstops_df.loc[pitstops_df['raceId'] == int(canada_2016_race_id)]
# Out:
# 954
#       raceId  driverId  stop  lap      time duration  milliseconds
# 4866     954       822     1   23  14:33:59   22.184         22184
# 4867     954         1     1   24  14:35:00   22.243         22243
# 4871     954        20     2   37  14:51:55   22.361         22361
# 4863     954         3     1   21  14:31:29   22.466         22466
# 4372     943       154     1   11  13:19:15   22.735         22735  2015
#
#                       name
# 1757     German Grand Prix
# 390     Chinese Grand Prix
# 5922    Russian Grand Prix
# 5993    British Grand Prix
# 4355    Chinese Grand Prix
# 39    Abu Dhabi Grand Prix
# 2934    Bahrain Grand Prix
# 1005   European Grand Prix
# 1651  Hungarian Grand Prix
# 4372    Mexican Grand Prix
#             raceId     driverId         stop          lap  milliseconds  \
# count  6251.000000  6251.000000  6251.000000  6251.000000  6.251000e+03
# mean    907.860342   429.468245     1.836346    24.813470  4.774453e+04
# std      44.327698   397.079565     0.935314    14.150022  1.791970e+05
# min     841.000000     1.000000     1.000000     1.000000  1.289700e+04
# 25%     868.000000    13.000000     1.000000    13.000000  2.176800e+04
# 50%     902.000000   807.000000     2.000000    24.000000  2.334000e+04
# 75%     950.000000   821.000000     2.000000    35.000000  2.554700e+04
# max     988.000000   843.000000     6.000000    74.000000  2.011266e+06
#
#               year
# count  6251.000000
# mean   2013.778595
# std       2.015840
# min    2011.000000
# 25%    2012.000000
# 50%    2014.000000
# 75%    2016.000000
# max    2017.000000

# %%
def race_name_dropdown_eventhandler(change):

    with out:
        clear_output()
        
        races_df.loc[(races_df['name'] == 'Canadian Grand Prix') & (races_df['year'] == 2016)]['raceId']
        display(year_slider.value)
        pitstops_for_chosen_gp_df = pitstops_2_df.loc[(pitstops_2_df['name'] == change.new) & (pitstops_2_df['year'] == year_slider.value)]
        display(pitstops_for_chosen_gp_df)


valid_pitstop_years = pitstops_2_df['year'].unique()
valid_pitstop_gp_names = pitstops_2_df['name'].unique()


year_slider = widgets.IntSlider(
                        min=int(pitstops_2_df['year'].min()),
                        max=int(pitstops_2_df['year'].max()),
                        step=1,
                        description='Year:',
                        value=3)

display(year_slider)

race_name_dropdown = widgets.Dropdown(options=valid_pitstop_gp_names,
                                    description='Select Grand Prix: ', disabled=False)

display(race_name_dropdown)
out = widgets.Output()
display(out)

race_name_dropdown.observe(race_name_dropdown_eventhandler, names='value')
# Out:
# IntSlider(value=2011, description='Year:', max=2017, min=2011)
# Dropdown(description='Select Grand Prix: ', options=('Abu Dhabi Grand Prix', 'Hungarian Grand Prix', 'Spanish …
# Output()

# %%
# !pip install qgrid


import qgrid

#qgrid.nbinstall(overwrite=True)  # copies javascript dependencies to your /nbextensions folder
#qgrid.set_defaults(remote_js=True)

# display(pitstops_2_df.sample(5))
qgrid.show_grid(pitstops_2_df, show_toolbar=False)

# %%
from ipywidgets import interact, interact_manual
import copy

@interact
def show_pitstops_more_than(column='milliseconds', x=60000):
    r = copy.deepcopy(pitstops_2_df.loc[pitstops_2_df[column] > x])
    r.sort_values('milliseconds', ascending=False, inplace=True)
    return r
